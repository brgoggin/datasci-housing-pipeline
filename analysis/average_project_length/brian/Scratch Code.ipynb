# %%
import pandas as pd
import logging
import dateutil
from dateutil import parser
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
from geopandas import GeoDataFrame
from shapely.geometry import Point
# %matplotlib inline
pd.set_option('display.max_columns', 500)

# %%
#import dataset of project times from "data" folder
file = "../../../data/cleaned/all_quarters__one_record_per_project.csv"
output="../../Output/"
df = pd.read_csv(file)

# %%
# Compare two files. Find differences
df1 = pd.read_csv(output+"/ex1.csv")
df2 = pd.read_csv(output+"/ex2.csv")

# %%
df1.shape
# Out:
# (713, 32)

# %%
df2.shape
# Out:
# (2248, 32)

# %%
df_both=df1.merge(df2, left_on=['address', 'apn'], right_on=['address', 'apn'], how='outer', indicator=True)

# %%
df_both.shape
# Out:
# (2257, 63)

# %%
df_both['_merge'].unique()
# Out:
# [both, left_only, right_only]
# Categories (3, object): [both, left_only, right_only]

# %%
df_both[df_both['_merge']=='left_only']
# Out:
#      Unnamed: 0_x  Unnamed: 0.1_x   BP_date_x  \
# 140         294.0         12717.0  2011-03-09
# 153        2942.0         16084.0  2012-08-09
# 193        2850.0         21424.0         NaN
# 352        1610.0         26437.0         NaN
# 356        3233.0         15504.0  2011-01-26
# 539        1809.0         27641.0         NaN
# 599         983.0         20217.0  2014-01-30
# 603         489.0         21511.0  2015-03-16
# 619        2285.0         13575.0  2008-04-25
#
#                                 address      apn best_date_x   best_stat_x  \
# 140                         25 ESSEX ST  3749064  2013-09-19  CONSTRUCTION
# 153                        235 BROADWAY  0165021  2014-09-19  CONSTRUCTION
# 193                            PARCEL F  0785029  2016-01-14  CONSTRUCTION
# 352           POTRERO1010 (BLDG 1 OF 2)  3833001  2016-05-26  CONSTRUCTION
# 356  1000 FOURTH STREET (BLOCK 13 EAST)  8711014  2014-05-09  CONSTRUCTION
# ...

# %%
df_both.head()
# Out:
#    Unnamed: 0_x  Unnamed: 0.1_x   BP_date_x            address       apn  \
# 0        2042.0         11295.0  2009-07-14   55 WATERVILLE ST   5379029
# 1        1028.0           575.0         NaN   2189 BAYSHORE BL  5066B007
# 2        1156.0         26951.0  2016-07-26         2 VESTA ST   5403001
# 3        1121.0         12215.0  2009-06-09      157 APOLLO ST   5405023
# 4        1500.0         12792.0  2011-02-22  6600 THIRD STREET   5476009
#
#   best_date_x   best_stat_x comp_date_x  con_date_x  dbi_permit_x  \
# 0  2012-07-27  CONSTRUCTION  04/01/2013  2011-05-20  200712049630
# 1  2009-03-09  CONSTRUCTION  10/01/2009  2009-03-09  200604148997
# 2  2016-11-21  CONSTRUCTION  01/01/2017  2016-11-21  201509237900
# 3  2013-05-10  CONSTRUCTION  07/01/2013  2013-04-09  200710105002
# 4  2013-08-29  CONSTRUCTION  10/01/2013  2012-07-13  201007196949
#
#   first_date_x first_project_record_date_x firstfiled_x  \
# 0   2007-12-04                  2009-07-14   2007-12-04
# ...
